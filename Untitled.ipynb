# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

# %%
df = pd.read_csv('kidney_disease.csv')

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.columns = ['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'anaemia', 'class']

# %%
df.describe()
# Out:
#                id         age  blood_pressure  specific_gravity     albumin  \
# count  400.000000  391.000000      388.000000        353.000000  354.000000
# mean   199.500000   51.483376       76.469072          1.017408    1.016949
# std    115.614301   17.169714       13.683637          0.005717    1.352679
# min      0.000000    2.000000       50.000000          1.005000    0.000000
# 25%     99.750000   42.000000       70.000000          1.010000    0.000000
# 50%    199.500000   55.000000       80.000000          1.020000    0.000000
# 75%    299.250000   64.500000       80.000000          1.020000    2.000000
# max    399.000000   90.000000      180.000000          1.025000    5.000000
#
#             sugar  blood_glucose_random  blood_urea  serum_creatinine  \
# count  351.000000            356.000000  381.000000        383.000000
# mean     0.450142            148.036517   57.425722          3.072454
# std      1.099191             79.281714   50.503006          5.741126
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
# ...

# %%
df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
# ...

# %%
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'], errors = 'coerce')
df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'], errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
num_cols = [col for col in df.columns if df[col].dtype != 'object']

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'anaemia',
#  'class']

# %%
num_cols
# Out:
# ['id',
#  'age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()} values\n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# anaemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
 df['diabetes_mellitus'] =df['diabetes_mellitus'].replace(to_replace = {' yes': 'yes', '\tno' : 'yes', '\tyes' : 'yes'})

# %%
df['diabetes_mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
# ...

# %%
df['pus_cell_clumps'].unique()
# Out:
# array(['notpresent', 'present', nan], dtype=object)

# %%
 df['coronary_artery_disease'] =df['coronary_artery_disease'].replace(to_replace = {' yes': 'yes', '\tno' : 'no', '\tyes' : 'yes'})

# %%
df
# Out:
#       id   age  blood_pressure  specific_gravity  albumin  sugar  \
# 0      0  48.0            80.0             1.020      1.0    0.0
# 1      1   7.0            50.0             1.020      4.0    0.0
# 2      2  62.0            80.0             1.010      2.0    3.0
# 3      3  48.0            70.0             1.005      4.0    0.0
# 4      4  51.0            80.0             1.010      2.0    0.0
# ..   ...   ...             ...               ...      ...    ...
# 395  395  55.0            80.0             1.020      0.0    0.0
# 396  396  42.0            70.0             1.025      0.0    0.0
# 397  397  12.0            80.0             1.020      0.0    0.0
# 398  398  17.0            60.0             1.025      0.0    0.0
# 399  399  58.0            80.0             1.025      0.0    0.0
#
#     red_blood_cells  pus_cell pus_cell_clumps    bacteria  ...  \
# 0               NaN    normal      notpresent  notpresent  ...
# ...

# %%
 df['class'] =df['class'].replace(to_replace = {'ckd\t' : 'ckd'})

# %%
df
# Out:
#       id   age  blood_pressure  specific_gravity  albumin  sugar  \
# 0      0  48.0            80.0             1.020      1.0    0.0
# 1      1   7.0            50.0             1.020      4.0    0.0
# 2      2  62.0            80.0             1.010      2.0    3.0
# 3      3  48.0            70.0             1.005      4.0    0.0
# 4      4  51.0            80.0             1.010      2.0    0.0
# ..   ...   ...             ...               ...      ...    ...
# 395  395  55.0            80.0             1.020      0.0    0.0
# 396  396  42.0            70.0             1.025      0.0    0.0
# 397  397  12.0            80.0             1.020      0.0    0.0
# 398  398  17.0            60.0             1.025      0.0    0.0
# 399  399  58.0            80.0             1.025      0.0    0.0
#
#     red_blood_cells  pus_cell pus_cell_clumps    bacteria  ...  \
# 0               NaN    normal      notpresent  notpresent  ...
# ...

# %%
df['class'].unique()
# Out:
# array(['ckd', 'notckd'], dtype=object)

# %%
df['class'] = df['class'].map({'ckd' : 0, 'notckd' : 1})

# %%
df['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Univariate analysis
plt.figure(figsize = (10, 6))
sns.histplot(df['age'].dropna(), kde = True
             , bins = 30, color = 'red')
plt.title('Dist of age')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
# Insights the average age of the people is 30

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'hypertension', data = df, palette = 'viridis')
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_21608\3089176886.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'hypertension', data = df, palette = 'viridis')
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
# Almost 150 of them has hypertension

# %%
sns.boxplot(x = 'class', y = 'blood_urea', data = df)
# Out:
# <Axes: xlabel='class', ylabel='blood_urea'>

# %%
# INsights class A has median which chronic desease

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'anaemia', data = df, palette = 'viridis')
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_21608\3564251776.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'anaemia', data = df, palette = 'viridis')
# <Axes: xlabel='anaemia', ylabel='count'>

# %%
# Insights -> 50 of the people have anemia

# %%
df.appetite.value_counts().plot.pie(autopct = '%1.1f%%', explode = (0, 0.1), startangle = 90)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['red_blood_cell_count'].dropna(), kde = True
             , bins = 30, color = 'red')
plt.title('Dist of age')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
sns.countplot(x = 'coronary_artery_disease', palette ='viridis', data = df)
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_21608\813461243.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'coronary_artery_disease', palette ='viridis', data = df)
# <Axes: xlabel='coronary_artery_disease', ylabel='count'>

# %%
sns.countplot(x = 'anaemia', data = df, palette = 'viridis')
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_21608\3564251776.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'anaemia', data = df, palette = 'viridis')
# <Axes: xlabel='anaemia', ylabel='count'>

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
# Bivariate analysis 
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
sns.scatterplot(x = 'age', y = 'blood_pressure', data = df, hue = 'class', palette = 'coolwarm')
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anaemia', 'class'],
#       dtype='object')

# %%
# Insights -> As the age increases the Blood pressure increases

# %%
sns.violinplot(x = 'diabetes_mellitus', y = 'albumin', data = df)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
# stacked bar chart
diabetes_hypertension = pd.crosstab(df['diabetes_mellitus'], df['hypertension'])
diabetes_hypertension
# Out:
# hypertension        no  yes
# diabetes_mellitus
# no                 247  117
# yes                  4   30

# %%
diabetes_hypertension.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='diabetes_mellitus'>

# %%
# Multivariate analysis



columns = ['age', 'blood_pressure', 'blood_glucose_random', 'serum_creatinine']
g = sns.PairGrid(df[columns + ['class']], hue='class', palette='coolwarm')

# Map the upper triangle with scatterplots
g.map_upper(sns.scatterplot)

# Map the lower triangle with KDE plots
g.map_lower(sns.kdeplot, fill=True)

# Map the diagonal with histograms
g.map_diag(sns.histplot)

# Add a legend
g.add_legend()

# Set the title for the entire PairGrid
g.fig.suptitle("PairGrid for selected columns", y=1.02)

# Display the plot
plt.show()

# %%
corr = df.corr(numeric_only = True)
plt.figure(figsize = (12, 8))
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >
